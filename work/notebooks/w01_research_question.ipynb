# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### My Lane: Refresh / Content Opportunity Scoring
#
# I chose the **Refresh / Content Opportunity Scoring** lane because websites often contain thousands of content pages, making manual review difficult and time-consuming. The goal of this project is to identify which pages should be reviewed first using search and engagement signals. This lane has clear business value because it helps prioritize limited resources and supports data-driven content decisions. It also allows me to apply machine learning to a real-world ranking problem.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ### Research Question
#
# **Question**
#
# Which content pages should be reviewed first for refresh based on their search and engagement signals?
#
# **Decision**
#
# Prioritize the pages that should be reviewed before others.
#
# **Unit of Analysis**
#
# One row represents one content page.
#
# **Output**
#
# A ranked list of content pages with a refresh opportunity score.
#
# **Who acts?**
#
# SEO specialists and content managers.
#
# **Cost of a wrong recommendation**
#
# If the model recommends the wrong pages, time may be spent reviewing pages that do not need updates, while pages that actually require attention may continue losing traffic. The goal is to support human decision-making rather than replace it.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

print("\nTrend Direction Distribution:")
print(df["trend_direction"].value_counts())

print("\nImpressions Statistics:")
print(df["impressions_90d"].describe())

df.head()

# %% [markdown]
# The starter dataset contains **30,000 content pages** with **44 features** describing search performance, engagement, and content characteristics.
#
# The average number of impressions over the last 90 days is **5,200.37**, while the median is **731**, showing that a relatively small number of pages receive very high traffic.
#
# The dataset contains **16,262 declining pages**, **5,962 stable pages**, **4,388 improving pages**, **2,236 new pages**, and **1,152 flat pages**. This variation suggests there is enough information to investigate which pages should be prioritized for content refresh.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What I can and can't claim
#
# This project analyzes observed search and engagement signals to identify pages that may benefit from review. The results provide decision support by ranking pages according to their estimated refresh opportunity.
#
# This project does not prove that refreshing a page will improve its search performance, nor does it predict Google's ranking algorithm. The recommendations are intended to support human decision-making and should be validated before action is taken.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
